# %%
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# We know that
# $$\tau = { {1\over C}} \exp {  {Kv}\over {kT} }$$
#
# Rearranging and taking the log of both sides, we get
# $$
# \hbox{ln }( \tau  C )= { {K {4} \pi r^3}\over {3kT} }.
# $$
# Solving for $r^3$ gives
# $$
# r^3 =   {3\over 4} { {kT}\over { K\pi} }ln \tau C.
# $$
#
# We  set $k= 1.38 \times 10^{-23}$J/K (Boltzmann's constant), $T=300$K (room temperature),  $C=10^{10}$s, and $K=1.3 \times 10^4$J/m$^3$ (the anisotropy constant for magnetite). Knowing that $d=2r$, we can write the script:

# %%
k=1.38e-23 # Boltzmann's constant
T=300 # room T
C=1e10 # frequency factor
K=1.3e4 # anisotropy constant for magnetite
taus=[.1,10,1e2,1e3,1e5,1e9,1e15,1e24]
print (' tau (s)  d (microns)')
for tau in taus:
    r3=((3./4.)*(k*T/(K*np.pi)))*np.log(tau*C) # equation relating r^3 to tau above. 
    r=r3**(1./3.) # take the cube root
    print ('%8.0e'%(tau), '  %5.3f'%(2*r*1e6)) # print tau (seconds) and d (in microns)
# Out:
#  tau (s)  d (microns)
#    1e-01   0.023
#    1e+01   0.025
#    1e+02   0.026
#    1e+03   0.026
#    1e+05   0.028
#    1e+09   0.030
#    1e+15   0.033
#    1e+24   0.036

# %%
def diameter_given_relaxation_time(tau, T, K, k, C):
    r3 = ((3./4.)*(k*T/(K*np.pi)))*np.log(tau*C) # equation relating r^3 to tau above. 
    r = r3**(1./3.) # take the cube root
    return r*2*1E9

# %%
diameter_list = []

for tau in taus:
    diameter = diameter_given_relaxation_time(tau, T, K, k, C)
    diameter_list.append(diameter)

# %%
diameter_list
# Out:
# [23.27227578834705,
#  24.882207842751278,
#  25.614453856444598,
#  26.30706931947468,
#  27.592333977272606,
#  29.854459899613133,
#  32.714329326338195,
#  36.24524091336682]

# %%
plt.scatter(diameter_list,taus)
plt.yscale('log')
plt.hlines(60*20,20,40,label='20 minutes')
plt.hlines(60*60*24*365*1e6,20,40,label='1 million years')
plt.hlines(60*60*24*365*1e9,20,40,label='1 billion years')
plt
plt.xlabel('diameter (nm)')
plt.ylabel('relaxation time (s)')
# Out:
# Text(0, 0.5, 'relaxation time (s)')

# %%
def v_K(K = np.linspace(1e-1, 3., num=100), tau = [100], C = 1e10, k = 1.38*1e-23, T = 300):
    
    fig, ax = plt.subplots(figsize = (15,10))
    
    for i in range(len(tau)):
        w = np.cbrt(np.log(tau[i]*C)*k*T/(K*1e4))
        ax.plot(w*1e9, K, color = 'C'+str(i), label = 'relaxation time (s): '+str('%.0E' % Decimal(tau[i])))
        
        ax.set_xlabel('Particular width (nm)')
        ax.set_ylabel('Anisotropy parameter ($10^{4}$)')
    return fig, ax

fig, ax = v_K(tau = [1e2, 1e4, 1e6, 1e8, 1e10])
# plt.yscale('log')
plt.legend()
plt.show(fig)

# %%
def plot_relaxation_width(width = np.linspace(1, 30)*1e-9, 
                          C = 1e10, 
                          K = 2.7*1e4, 
                          k = 1.38*1e-23, 
                          T = [300]):

    volume = width**3*1.3
    
    fig, ax = plt.subplots(figsize = (15,10))
    
    for i in range(len(T)):  
        tau = 1/C*np.exp((volume*K)/(2*k*T[i]))
        ax.plot(width*1e9,tau, color = 'C'+str(i), label = 'Temp (K): '+ str(T[i]))
  
    ax.set_yscale('log')
    ax.set_xlabel('Particle width (nm)')
    ax.set_ylabel('Relaxation time (seconds)')
    
    return  fig, ax

fig, ax = plot_relaxation_width(T = [300, 400, 500, 600, 700, 800])

plt.legend()
plt.show(fig)

# print(tau)
